# %%
from spe import SineSPE
import torch

# %%
m = SineSPE(num_sines=16)

# %%
batch_size = 4
t = 1000

# %%
inp = torch.randn((batch_size, t))

# %%
res = m((batch_size, t))
# Out:
# torch.Size([8, 64, 1, 16])
# torch.Size([8, 64, 1000, 16])
# torch.Size([1, 8, 64, 1000, 32])
